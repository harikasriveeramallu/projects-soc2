# %%
import requests
api_key="f250b92b1c974684b718846ff6ec0b03"

url=f"https://newsapi.org/v2/everything?q=tesla&from=2024-01-28&sortBy=publishedAt&apiKey=f250b92b1c974684b718846ff6ec0b03"

response=requests.get(url)
data=response.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 12426, 'articles': [{'source': {'id': None, 'name': 'Dinheirama.com'}, 'author': 'Reuters', 'title': 'Dow Jones lidera perdas em Wall Street antes de dados econômicos', 'description': 'O índice Dow Jones liderava as quedas em Wall Street nesta terça-feira, com investidores aguardando um relatório crucial sobre a inflação e outros dados econômicos…\n------ Este artigo foi escrito por Reuters. Este artigo apareceu originalmente no site Dinheir…', 'url': 'https://dinheirama.com/dow-jones-lidera-perdas-em-wall-street-antes-de-dados-economicos/', 'urlToImage': 'https://media.dinheirama.com/medias/uploads/2023/10/20231006-wall-street.jpg', 'publishedAt': '2024-02-27T16:02:57Z', 'content': '2O índice Dow Jones liderava as quedas em Wall Street nesta terça-feira, com investidores aguardando um relatório crucial sobre a inflação e outros dados econômicos que devem moldar as expectativas d… [+2458 chars]'}, {'source': {'id': None, 'name': 'Bright.nl'}, 'author'
# ...

# %%
import requests

url = "https://distance-calculator8.p.rapidapi.com/calc"

querystring = {"startLatitude":"-89.311960", "startLongitude":"-28.880964","endLatitude":"-36.313662","endLongitude":"-48.881103"}
headers = {
    "X-RapidAPI-Key": "8266ba0ebbmshedb8ed8b6037119p126fb2jsn2ad1740182cc",

    "X-RapidAPI-Host": "distance-calculator8.p.rapidapi.com"
}
response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'statusCode': 200, 'body': {'distance': {'meters': 5897795.860560813, 'kilometers': 5897.795860560813, 'miles': 3664.7295540785744}}}
